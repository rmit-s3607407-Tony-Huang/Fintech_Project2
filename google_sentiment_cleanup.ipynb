# %%
# import pandas to combine dataframes
import pandas as pd

# %%
# Opening the 1st partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment0 = pd.read_csv('Data/google_sentiment_df_0_90.csv', parse_dates=True, index_col = "date")

# 2017-11-15 was a duplicate date, so we drop the row
google_sentiment0 = google_sentiment0.drop('2017-11-16 11:00:00')
google_sentiment0
# Out:
#                      Unnamed: 0  \
# date
# 2017-08-18 10:00:00           0
# 2017-08-19 10:00:00           1
# 2017-08-20 10:00:00           2
# 2017-08-21 10:00:00           3
# 2017-08-22 10:00:00           4
# ...                         ...
# 2017-11-11 11:00:00          85
# 2017-11-12 11:00:00          86
# 2017-11-13 11:00:00          87
# 2017-11-14 11:00:00          88
# 2017-11-15 11:00:00          89
#
#                                                                   text  \
# date
# 2017-08-18 10:00:00  Hedge funds have long been a popular choice fo...
# 2017-08-19 10:00:00  Gemini also acknowledges this is not their fir...
# 2017-08-20 10:00:00  Bitcoin ATM company LocalCoinATM recently open...
# 2017-08-21 10:00:00  Members of the U.S. Congress are drafting legi...
# 2017-08-22 10:00:00  Aug.22 -- Ben Brabyn, head of Level39, discuss...
# ...                                                                ...
# ...

# %%
# Opening the 2nd partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment1 = pd.read_csv('Data/google_sentiment_df_90_180.csv', parse_dates=True, index_col = "date")

# 2018-02-14 was a duplicate date, so we drop the row
google_sentiment1 = google_sentiment1.drop('2018-02-14 11:00:00')
google_sentiment1
# Out:
#                      Unnamed: 0  \
# date
# 2017-11-16 11:00:00           0
# 2017-11-17 11:00:00           1
# 2017-11-18 11:00:00           2
# 2017-11-19 11:00:00           3
# 2017-11-20 11:00:00           4
# ...                         ...
# 2018-02-09 11:00:00          85
# 2018-02-10 11:00:00          86
# 2018-02-11 11:00:00          87
# 2018-02-12 11:00:00          88
# 2018-02-13 11:00:00          89
#
#                                                                   text  \
# date
# 2017-11-16 11:00:00  You can think of satoshi as the “penny” of Bit...
# 2017-11-17 11:00:00  Police say they have limited ability to help v...
# 2017-11-18 11:00:00  In an interview with Bloomberg, the chief inve...
# 2017-11-19 11:00:00  Monero mining is very simple. You can mine XMR...
# 2017-11-20 11:00:00  One million yen is quite a lot of money for th...
# ...                                                                ...
# ...

# %%
# Opening the 3rd partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment2 = pd.read_csv('Data/google_sentiment_df_180_270.csv', parse_dates=True, index_col = "date")
google_sentiment2
# Out:
#                      Unnamed: 0  \
# date
# 2018-02-14 11:00:00           0
# 2018-02-15 11:00:00           1
# 2018-02-16 11:00:00           2
# 2018-02-17 11:00:00           3
# 2018-02-18 11:00:00           4
# ...                         ...
# 2018-05-10 10:00:00          85
# 2018-05-11 10:00:00          86
# 2018-05-12 10:00:00          87
# 2018-05-13 10:00:00          88
# 2018-05-14 10:00:00          89
#
#                                                                   text  \
# date
# 2018-02-14 11:00:00  Spoofy is the nickname for a mysterious crypto...
# 2018-02-15 11:00:00  In February 2018 before the crypto bear market...
# 2018-02-16 11:00:00  Abonnez-vous à notre chaîne sur YouTube : http...
# 2018-02-17 11:00:00  Companies thinking of riding the blockchain wa...
# 2018-02-18 11:00:00  An estimated £3-4bn is being laundered via cry...
# ...                                                                ...
# ...

# %%
# Opening the 4th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment3 = pd.read_csv('Data/google_sentiment_df_270_360.csv', parse_dates=True, index_col = "date")
google_sentiment3
# Out:
#                      Unnamed: 0  \
# date
# 2018-05-15 10:00:00           0
# 2018-05-16 10:00:00           1
# 2018-05-17 10:00:00           2
# 2018-05-18 10:00:00           3
# 2018-05-19 10:00:00           4
# ...                         ...
# 2018-08-08 10:00:00          85
# 2018-08-09 10:00:00          86
# 2018-08-10 10:00:00          87
# 2018-08-11 10:00:00          88
# 2018-08-12 10:00:00          89
#
#                                                                   text  \
# date
# 2018-05-15 10:00:00  This is it. This is my most advanced technical...
# 2018-05-16 10:00:00  One of the highest level executives at JPMorga...
# 2018-05-17 10:00:00  New estimates and models find that by the end ...
# 2018-05-18 10:00:00  The co-founder of technology giant Apple has o...
# 2018-05-19 10:00:00  As cryptocurrency interest and trading continu...
# ...                                                                ...
# ...

# %%
# Opening the 5th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment4 = pd.read_csv('Data/google_sentiment_df_360_450.csv', parse_dates=True, index_col = "date")
google_sentiment4
# Out:
#                      Unnamed: 0  \
# date
# 2018-08-13 10:00:00           0
# 2018-08-14 10:00:00           1
# 2018-08-15 10:00:00           2
# 2018-08-16 10:00:00           3
# 2018-08-17 10:00:00           4
# ...                         ...
# 2018-11-06 11:00:00          85
# 2018-11-07 11:00:00          86
# 2018-11-08 11:00:00          87
# 2018-11-09 11:00:00          88
# 2018-11-10 11:00:00          89
#
#                                                                   text  \
# date
# 2018-08-13 10:00:00  While Bitcoin has fallen more than the lira in...
# 2018-08-14 10:00:00  A 32-year-old has revealed his eye-watering $3...
# 2018-08-15 10:00:00  Bitcoin has taken over all forms of media, fro...
# 2018-08-16 10:00:00  Cryptocurrency markets are tentatively posting...
# 2018-08-17 10:00:00  The largest US-based cryptocurrency exchange h...
# ...                                                                ...
# ...

# %%
# Opening the 6th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment5 = pd.read_csv('Data/google_sentiment_df_450_540.csv', parse_dates=True, index_col = "date")
google_sentiment5
# Out:
#                      Unnamed: 0  \
# date
# 2018-11-11 11:00:00           0
# 2018-11-12 11:00:00           1
# 2018-11-13 11:00:00           2
# 2018-11-14 11:00:00           3
# 2018-11-15 11:00:00           4
# ...                         ...
# 2019-02-04 11:00:00          85
# 2019-02-05 11:00:00          86
# 2019-02-06 11:00:00          87
# 2019-02-07 11:00:00          88
# 2019-02-08 11:00:00          89
#
#                                                                   text  \
# date
# 2018-11-11 11:00:00  Numerous signs of maturity can be noted across...
# 2018-11-12 11:00:00  Leader in cryptocurrency, Bitcoin, Ethereum, X...
# 2018-11-13 11:00:00  Hackers were able to compromise Target's Twitt...
# 2018-11-14 11:00:00  Read my TREZOR One hardware wallet review. Fin...
# 2018-11-15 11:00:00  Bitcoin price has been fluctuating highly in t...
# ...                                                                ...
# ...

# %%
# Opening the 7th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment6 = pd.read_csv('Data/google_sentiment_df_540_630.csv', parse_dates=True, index_col = "date")
google_sentiment6
# Out:
#                      Unnamed: 0  \
# date
# 2019-02-09 11:00:00           0
# 2019-02-10 11:00:00           1
# 2019-02-11 11:00:00           2
# 2019-02-12 11:00:00           3
# 2019-02-13 11:00:00           4
# ...                         ...
# 2019-05-05 10:00:00          85
# 2019-05-06 10:00:00          86
# 2019-05-07 10:00:00          87
# 2019-05-08 10:00:00          88
# 2019-05-09 10:00:00          89
#
#                                                                   text  \
# date
# 2019-02-09 11:00:00  In its slow-but-steady crawl towards mass adop...
# 2019-02-10 11:00:00  A now-Vancouver-based Silicon Valley developer...
# 2019-02-11 11:00:00  If you are a fan of betting and also a firm be...
# 2019-02-12 11:00:00  "Das ist keine normale historische Entwicklung...
# 2019-02-13 11:00:00  Things have been busy in crypto land this week...
# ...                                                                ...
# ...

# %%
# Opening the 8th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment7 = pd.read_csv('Data/google_sentiment_df_630_714.csv', parse_dates=True, index_col = "date")
google_sentiment7
# Out:
#                      Unnamed: 0  \
# date
# 2019-05-10 10:00:00           0
# 2019-05-11 10:00:00           1
# 2019-05-12 10:00:00           2
# 2019-05-13 10:00:00           3
# 2019-05-14 10:00:00           4
# ...                         ...
# 2019-07-27 10:00:00          78
# 2019-07-28 10:00:00          79
# 2019-07-29 10:00:00          80
# 2019-07-30 10:00:00          81
# 2019-07-31 10:00:00          82
#
#                                                                   text  \
# date
# 2019-05-10 10:00:00  A recent run-up in the bitcoin price has been ...
# 2019-05-11 10:00:00  Bitcoin, the world's largest cryptocurrency by...
# 2019-05-12 10:00:00  Bitcoin went absolutely parabolic over the wee...
# 2019-05-13 10:00:00  Goldman Sachs economists believe the trade war...
# 2019-05-14 10:00:00  Kevin O'Leary has stated that Bitcoin is "garb...
# ...                                                                ...
# ...

# %%
# Opening the 9th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment8 = pd.read_csv('Data/google_sentiment_df_713_803.csv', parse_dates=True, index_col = "date")
google_sentiment8
# Out:
#                      Unnamed: 0  \
# date
# 2019-08-01 10:00:00           0
# 2019-08-02 10:00:00           1
# 2019-08-03 10:00:00           2
# 2019-08-04 10:00:00           3
# 2019-08-05 10:00:00           4
# ...                         ...
# 2019-10-25 11:00:00          85
# 2019-10-26 11:00:00          86
# 2019-10-27 11:00:00          87
# 2019-10-28 11:00:00          88
# 2019-10-29 11:00:00          89
#
#                                                                   text  \
# date
# 2019-08-01 10:00:00  Some are bullish, while others are bearish.Sub...
# 2019-08-02 10:00:00  Cryptotrader looks at how we should trade in c...
# 2019-08-03 10:00:00  One of the world's largest digital currency as...
# 2019-08-04 10:00:00  Bitcoin SV experienced a serious network split...
# 2019-08-05 10:00:00  Wondering what is Ethereum (ETH)? - A decentra...
# ...                                                                ...
# ...

# %%
# Opening the 10th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment9 = pd.read_csv('Data/google_sentiment_df_803_893.csv', parse_dates=True, index_col = "date")
google_sentiment9
# Out:
#                      Unnamed: 0  \
# date
# 2019-10-30 11:00:00           0
# 2019-10-31 11:00:00           1
# 2019-11-01 11:00:00           2
# 2019-11-02 11:00:00           3
# 2019-11-03 11:00:00           4
# ...                         ...
# 2020-01-23 11:00:00          85
# 2020-01-24 11:00:00          86
# 2020-01-25 11:00:00          87
# 2020-01-26 11:00:00          88
# 2020-01-27 11:00:00          89
#
#                                                                   text  \
# date
# 2019-10-30 11:00:00  There's a theory, dubbed “The Halloween Effect...
# 2019-10-31 11:00:00  Could Bitcoin (BTC) benefit from growing numbe...
# 2019-11-01 11:00:00  Bitcoin has been trading sideways for quite so...
# 2019-11-02 11:00:00  What happens to Bitcoin after 2140? Will bitco...
# 2019-11-03 11:00:00  Minería #Bitcoin #CriptomonedasEn este tutoria...
# ...                                                                ...
# ...

# %%
# Opening the 11th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment10 = pd.read_csv('Data/google_sentiment_df_893_983.csv', parse_dates=True, index_col = "date")
google_sentiment10
# Out:
#                      Unnamed: 0  \
# date
# 2020-01-28 11:00:00           0
# 2020-01-29 11:00:00           1
# 2020-01-30 11:00:00           2
# 2020-01-31 11:00:00           3
# 2020-02-01 11:00:00           4
# ...                         ...
# 2020-04-22 10:00:00          85
# 2020-04-23 10:00:00          86
# 2020-04-24 10:00:00          87
# 2020-04-25 10:00:00          88
# 2020-04-26 10:00:00          89
#
#                                                                   text  \
# date
# 2020-01-28 11:00:00  The index fund plans to capture $1.01b (US$750...
# 2020-01-29 11:00:00  XRP, the cryptocurrency commonly called Ripple...
# 2020-01-30 11:00:00  Jan.30 -- Billionaire Bitcoin maven Mike Novog...
# 2020-01-31 11:00:00  Bitcoin could become an $8 trillion asset by 2...
# 2020-02-01 11:00:00  Bitcoin price traded to a new 2020 high at $95...
# ...                                                                ...
# ...

# %%
# Opening the 12th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment11 = pd.read_csv('Data/google_sentiment_df_983_1073.csv', parse_dates=True, index_col = "date")
google_sentiment11
# Out:
#                      Unnamed: 0  \
# date
# 2020-04-27 10:00:00           0
# 2020-04-28 10:00:00           1
# 2020-04-29 10:00:00           2
# 2020-04-30 10:00:00           3
# 2020-05-01 10:00:00           4
# ...                         ...
# 2020-07-21 10:00:00          85
# 2020-07-22 10:00:00          86
# 2020-07-23 10:00:00          87
# 2020-07-24 10:00:00          88
# 2020-07-25 10:00:00          89
#
#                                                                   text  \
# date
# 2020-04-27 10:00:00  Bitcoin's implied volatility has cratered in r...
# 2020-04-28 10:00:00  After trading below $7.800 for days on end, Bi...
# 2020-04-29 10:00:00  The correlation between Bitcoin and the S&P 50...
# 2020-04-30 10:00:00  As the bull rally continues, some Bitcoin tech...
# 2020-05-01 10:00:00  The past few days have undoubtedly been bullis...
# ...                                                                ...
# ...

# %%
# Opening the 13th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment12 = pd.read_csv('Data/google_sentiment_df_1073_1163.csv', parse_dates=True, index_col = "date")
google_sentiment12
# Out:
#                      Unnamed: 0  \
# date
# 2020-07-26 10:00:00           0
# 2020-07-27 10:00:00           1
# 2020-07-28 10:00:00           2
# 2020-07-29 10:00:00           3
# 2020-07-30 10:00:00           4
# ...                         ...
# 2020-10-19 11:00:00          85
# 2020-10-20 11:00:00          86
# 2020-10-21 11:00:00          87
# 2020-10-22 11:00:00          88
# 2020-10-23 11:00:00          89
#
#                                                                   text  \
# date
# 2020-07-26 10:00:00  IOHK CEO Charles Hoskinson shared his predicti...
# 2020-07-27 10:00:00  Robinhood is a commission-free trading platfor...
# 2020-07-28 10:00:00  Bitcoin is struggling to gain momentum above t...
# 2020-07-29 10:00:00  Bitcoin price this week broke up from consolid...
# 2020-07-30 10:00:00  Fidelity Digital Assets has released a new rep...
# ...                                                                ...
# ...

# %%
# Opening the 14th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment13 = pd.read_csv('Data/google_sentiment_df_1163_1253.csv', parse_dates=True, index_col = "date")
google_sentiment13
# Out:
#                      Unnamed: 0  \
# date
# 2020-10-24 11:00:00           0
# 2020-10-25 11:00:00           1
# 2020-10-26 11:00:00           2
# 2020-10-27 11:00:00           3
# 2020-10-28 11:00:00           4
# ...                         ...
# 2021-01-17 11:00:00          85
# 2021-01-18 11:00:00          86
# 2021-01-19 11:00:00          87
# 2021-01-20 11:00:00          88
# 2021-01-21 11:00:00          89
#
#                                                                   text  \
# date
# 2020-10-24 11:00:00  There are a few bearish signs arising, includi...
# 2020-10-25 11:00:00  JP Morgan says bitcoin's 2020 surge is set to ...
# 2020-10-26 11:00:00  October 2020 - Michael Saylor is an American e...
# 2020-10-27 11:00:00  Funding rate of the Bitcoin futures is turning...
# 2020-10-28 11:00:00  Bitcoin has undergone a strong drop since the ...
# ...                                                                ...
# ...

# %%
# Opening the 15th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment14 = pd.read_csv('Data/google_sentiment_df_1253_1343.csv', parse_dates=True, index_col = "date")
google_sentiment14
# Out:
#                      Unnamed: 0  \
# date
# 2021-01-22 11:00:00           0
# 2021-01-23 11:00:00           1
# 2021-01-24 11:00:00           2
# 2021-01-25 11:00:00           3
# 2021-01-26 11:00:00           4
# ...                         ...
# 2021-04-17 10:00:00          85
# 2021-04-18 10:00:00          86
# 2021-04-19 10:00:00          87
# 2021-04-20 10:00:00          88
# 2021-04-21 10:00:00          89
#
#                                                                   text  \
# date
# 2021-01-22 11:00:00  Anthony Pompliano, author of the Pomp Letter, ...
# 2021-01-23 11:00:00  After telling his huge online following to buy...
# 2021-01-24 11:00:00  The Guardian's UK technology editor, Alex Hern...
# 2021-01-25 11:00:00  With both Bitcoin price and DeFi's total value...
# 2021-01-26 11:00:00  Dubbed the 'Godfather of Bitcoin', American in...
# ...                                                                ...
# ...

# %%
# Opening the 16th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment15 = pd.read_csv('Data/google_sentiment_df_1343_1433.csv', parse_dates=True, index_col = "date")
google_sentiment15
# Out:
#                      Unnamed: 0  \
# date
# 2021-04-22 10:00:00           0
# 2021-04-23 10:00:00           1
# 2021-04-24 10:00:00           2
# 2021-04-25 10:00:00           3
# 2021-04-26 10:00:00           4
# ...                         ...
# 2021-07-16 10:00:00          85
# 2021-07-17 10:00:00          86
# 2021-07-18 10:00:00          87
# 2021-07-19 10:00:00          88
# 2021-07-20 10:00:00          89
#
#                                                                   text  \
# date
# 2021-04-22 10:00:00  It's the showdown that everyone has been waiti...
# 2021-04-23 10:00:00  Bitcoin price has erupted to more than $55000,...
# 2021-04-24 10:00:00  Download Simplest Bitcoin App : CoinDCX Go - h...
# 2021-04-25 10:00:00  Why is #DogeCoinToTheMoon trending? What is #B...
# 2021-04-26 10:00:00  The price of bitcoin headed towards bearish te...
# ...                                                                ...
# ...

# %%
# Opening the 17th partition of google sentiment, print to see if the end date aligns with the next dataframe
google_sentiment16 = pd.read_csv('Data/google_sentiment_df_1433_1523.csv', parse_dates=True, index_col = "date")
google_sentiment16
# Out:
#                      Unnamed: 0  \
# date
# 2021-07-21 10:00:00           0
# 2021-07-22 10:00:00           1
# 2021-07-23 10:00:00           2
# 2021-07-24 10:00:00           3
# 2021-07-25 10:00:00           4
# ...                         ...
# 2021-10-14 11:00:00          85
# 2021-10-15 11:00:00          86
# 2021-10-16 11:00:00          87
# 2021-10-17 11:00:00          88
# 2021-10-18 11:00:00          89
#
#                                                                   text  \
# date
# 2021-07-21 10:00:00  At the B Word conference, Elon Musk explains h...
# 2021-07-22 10:00:00  Bitcoins are discovered rather than printed. C...
# 2021-07-23 10:00:00  Bitcoin remains the world's most popular crypt...
# 2021-07-24 10:00:00  The bitcoin and crypto market boost comes afte...
# 2021-07-25 10:00:00  Bitcoin price found support near $36400 and it...
# ...                                                                ...
# ...

# %%
# After verifying all the partial dataframes to ensure the dates are continuous, we concatenate them into a single dataframe and drop unnecessary columns.
google_sentiment = pd.concat([google_sentiment0,google_sentiment1,
                                google_sentiment2,google_sentiment3,
                                google_sentiment4,google_sentiment5,
                                google_sentiment6,google_sentiment7,
                                google_sentiment8,google_sentiment9,
                                google_sentiment10,google_sentiment11,
                                google_sentiment12,google_sentiment13,
                                google_sentiment14,google_sentiment15,
                                google_sentiment16])
google_sentiment.drop('Unnamed: 0', axis=1, inplace=True)
google_sentiment = google_sentiment.rename(columns={"text":"Google text"})
google_sentiment
# Out:
#                                                            Google text  \
# date
# 2017-08-18 10:00:00  Hedge funds have long been a popular choice fo...
# 2017-08-19 10:00:00  Gemini also acknowledges this is not their fir...
# 2017-08-20 10:00:00  Bitcoin ATM company LocalCoinATM recently open...
# 2017-08-21 10:00:00  Members of the U.S. Congress are drafting legi...
# 2017-08-22 10:00:00  Aug.22 -- Ben Brabyn, head of Level39, discuss...
# ...                                                                ...
# 2021-10-14 11:00:00  The rapidly growing world of Bitcoin ETFs will...
# 2021-10-15 11:00:00  Forbes - Bitcoin prices have rallied by almost...
# 2021-10-16 11:00:00  The approval of a Bitcoin Exchange Traded Fund...
# 2021-10-17 11:00:00  Leader in cryptocurrency, Bitcoin, Ethereum, X...
# 2021-10-18 11:00:00  Even superheroes like the Bitcoin Core Develop...
#
#                      Google compound  Google positive  Google negative  \
# date
# ...

# %%
# Save the dataframe into its own csv file
google_sentiment.to_csv('google_sentiment_df.csv')
